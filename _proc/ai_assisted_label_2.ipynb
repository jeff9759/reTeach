# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(classify_unlabeled_texts)
# Out:
# ---
#
# ### classify_unlabeled_texts
#
# >      classify_unlabeled_texts (df, text_column, label_column)

# %%
#| echo: false
#| output: asis
show_doc(start_to_label)
# Out:
# ---
#
# ### start_to_label
#
# >      start_to_label (uploaded_file, chunk_size, text_column='Text',
# >                      label_column='Label')

# %%
#| echo: false
#| output: asis
show_doc(correct_dataframe)
# Out:
# ---
#
# ### correct_dataframe
#
# >      correct_dataframe (dataframe_display, file_input, current_dataframe,
# >                         accuracy_log, chunk_size, chunk_count,
# >                         text_column='Text', label_column='Label')

# %%
#| echo: false
#| output: asis
show_doc(create_plot)
# Out:
# ---
#
# ### create_plot
#
# >      create_plot (accuracy_log, save_path='plot.png')

# %%
# key_dict = json.load(open('../api_key.json', 'r'))
# for key in key_dict:
#     os.environ[key] = key_dict[key]

# df = pd.read_csv('../data/009-1.csv')
# response = classify_unlabeled_texts(df, 'Text', 'Label')
# print(response)
# print(new_df)

# %%
# print(response['Label'].isna().sum())
